# %% [markdown]
# ### Data Analysis

# %%
import json
import numpy as np
import pandas as pd

# %%
with open("data/database/sample.json", 'r') as f:
    sample = json.load(f)

# %%
dict_keys(['ID', 'age', 'gender', 'home_address', 'foreign_address', 'profession',
           'date_out', 'date_return', 'fund2invest', 'personal_view'])

# %%
len(sample)
# Out:
# 100

# %%
for item in sample:
    print(item.keys()) 
    break
# Out:
# dict_keys(['ID', 'age', 'gender', 'home_address', 'foreign_address', 'profession', 'date_out', 'date_return', 'fund2invest', 'personal_view'])

# %%
for item in sample:
    print(item.values()) 
    break
# Out:
# dict_values(['87X74184VP', 42, 'male', {'province': 'PN7', 'district': 'Bajura', 'MCP': 'Budhi Nanda MCP', 'ward': 'Ward 5'}, {'country': 'Afghanistan', 'ID': 'AF', 'lat': '-19.015438', 'lon': '29.154857', 'city': 'ANDORRA LA VELLA'}, {'major': 'Computer and Mathematical Occupations', 'branch': 'Mathematical Science Occupations, All Other'}, '2019.8.28', '2025.7.17', 6105, ['Kathmandu Metropolitan City’s undying infatuation for the preface ‘smart’ has manifested in several glossy (and costly) infrastructural undertakings—from zebra crossings to dustbins and even toilets. But contrary to what ‘smart’ suggests, many of these initiatives seem devoid of any intelligent or sustainable solutions to the challenges they claim to address.Take, for example, the ‘smart dustbins’. From November last year, Kathmandu Metropolitan City, in conjunction with its private partner Krishna Suppliers, began scattering over 70 ‘smart dustbins’ throughout the city. According to city officials, each dustbin,
# ...

# %%
DF = pd.DataFrame(sample)

# %%
DF.head()
# Out:
#            ID  age    date_out date_return  \
# 0  87X74184VP   42   2019.8.28   2025.7.17
# 1  KF9JC738X7   31  2013.11.27    2021.7.7
# 2  8590HKYF9X   35   2014.3.23  2023.10.21
# 3  558VC330X3   43  2017.12.27   2020.6.30
# 4  65L3SQO9P1   35  2011.10.16   2023.4.21
#
#                                      foreign_address  fund2invest  gender  \
# 0  {'country': 'Afghanistan', 'ID': 'AF', 'lat': ...         6105    male
# 1  {'country': 'Nepal', 'ID': 'NP', 'lat': '-19.0...          962    male
# 2  {'country': 'San-Marino', 'ID': 'SM', 'lat': '...         9383    male
# 3  {'country': 'Dominican-Republic', 'ID': 'DO', ...         6075  female
# 4  {'country': 'Turks-and-Caicos-Islands', 'ID': ...         2008  female
#
#                                         home_address  \
# 0  {'province': 'PN7', 'district': 'Bajura', 'MCP...
# 1  {'province': 'PN1', 'district': 'Taplejung', '...
# 2  {'province': 'PN5', 'district': 'Palpa', 'MCP'...
# ...

# %%
DF = DF.set_index('ID')

# %%
DF.head()
# Out:
#             age    date_out date_return  \
# ID
# 87X74184VP   42   2019.8.28   2025.7.17
# KF9JC738X7   31  2013.11.27    2021.7.7
# 8590HKYF9X   35   2014.3.23  2023.10.21
# 558VC330X3   43  2017.12.27   2020.6.30
# 65L3SQO9P1   35  2011.10.16   2023.4.21
#
#                                               foreign_address  fund2invest  \
# ID
# 87X74184VP  {'country': 'Afghanistan', 'ID': 'AF', 'lat': ...         6105
# KF9JC738X7  {'country': 'Nepal', 'ID': 'NP', 'lat': '-19.0...          962
# 8590HKYF9X  {'country': 'San-Marino', 'ID': 'SM', 'lat': '...         9383
# 558VC330X3  {'country': 'Dominican-Republic', 'ID': 'DO', ...         6075
# 65L3SQO9P1  {'country': 'Turks-and-Caicos-Islands', 'ID': ...         2008
#
#             gender                                       home_address  \
# ID
# 87X74184VP    male  {'province': 'PN7', 'district': 'Bajura', 'MCP...
# KF9JC738X7    male  {'province': 'PN1', 'district': 'Taplejung', '...
# ...

# %% [markdown]
# ### Data Processing

# %% [markdown]
# 1. Drop views
# 2. Seperate home address [PN,District,MCP,Ward]
# 3. Seperate Foreign address [country,lat,long,city]
# 4. Use lambda function $1000 = $1K
# 5. Create new column [month] with total month duration between data out-date return
# 6.

# %% [markdown]
# #### Data Exploration

# %%
1. Age distribution ?
2. Gender and age - correlation?
3. County- gender ? Country- age ?
4. Histogram, bar-plot, ven-diagram ?

# %% [markdown]
# #### Data modeling - Machine lerning ( Scikit-learn)

# %%
1. Linear-regression, 
2. Classifier

# %% [markdown]
# #### Data Visualization ( matplotlib.pyplot, seaborn, Bokeh, plotly(Python-API)) (D3.JS, chart.js)

# %%
1. Plot generation

# %% [markdown]
# ----------

# %%
Data = []
k = 0
for item in sample:
    print(item.values()) 
    ID = item['ID']
    age = item['age']
    country = item['foreign_address']['country']
    lat = item['foreign_address']['lat']
    
    Data.append({'ID': ID, "age":age,\
                "country": country,\
                "lat": lat})
    k +=k
    if k> 10:
        break
# Out:
# dict_values(['87X74184VP', 42, 'male', {'province': 'PN7', 'district': 'Bajura', 'MCP': 'Budhi Nanda MCP', 'ward': 'Ward 5'}, {'country': 'Afghanistan', 'ID': 'AF', 'lat': '-19.015438', 'lon': '29.154857', 'city': 'ANDORRA LA VELLA'}, {'major': 'Computer and Mathematical Occupations', 'branch': 'Mathematical Science Occupations, All Other'}, '2019.8.28', '2025.7.17', 6105, ['Kathmandu Metropolitan City’s undying infatuation for the preface ‘smart’ has manifested in several glossy (and costly) infrastructural undertakings—from zebra crossings to dustbins and even toilets. But contrary to what ‘smart’ suggests, many of these initiatives seem devoid of any intelligent or sustainable solutions to the challenges they claim to address.Take, for example, the ‘smart dustbins’. From November last year, Kathmandu Metropolitan City, in conjunction with its private partner Krishna Suppliers, began scattering over 70 ‘smart dustbins’ throughout the city. According to city officials, each dustbin,
# ...

# %%
Data
# Out:
# [{'ID': '87X74184VP',
#   'age': 42,
#   'country': 'Afghanistan',
#   'lat': '-19.015438'},
#  {'ID': 'KF9JC738X7', 'age': 31, 'country': 'Nepal', 'lat': '-19.015438'},
#  {'ID': '8590HKYF9X', 'age': 35, 'country': 'San-Marino', 'lat': '-19.015438'},
#  {'ID': '558VC330X3',
#   'age': 43,
#   'country': 'Dominican-Republic',
#   'lat': '-19.015438'},
#  {'ID': '65L3SQO9P1',
#   'age': 35,
#   'country': 'Turks-and-Caicos-Islands',
#   'lat': '-19.015438'},
#  {'ID': 'I0I7GJX25L',
#   'age': 48,
#   'country': 'Saint-Pierre-and-Miquelon',
#   'lat': '-19.015438'},
#  {'ID': 'T465L500DQ', 'age': 50, 'country': 'Malaysia', 'lat': '-19.015438'},
#  {'ID': 'UB98EZKC8V', 'age': 26, 'country': 'Belarus', 'lat': '-19.015438'},
#  {'ID': 'K188J88GS7',
#   'age': 43,
#   'country': 'Congo-[DRC]',
#   'lat': '-19.015438'},
#  {'ID': '695Y9BCZK8', 'age': 31, 'country': 'Chad', 'lat': '-19.015438'},
#  {'ID': 'TVTA94T275',
#   'age': 46,
#   'country': 'São-Tomé-and-Príncipe',
# ...

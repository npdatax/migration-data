# %% [markdown]
# ## A Random Person

# %%
import json as json
import random as random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
from generator.person import *

# %%
with open("data/world/world.json", 'r') as f1:
    world = json.load(f1)

# %%
with open("data/nepal/NepalG.json", 'r') as f2:
    nepal = json.load(f2)

# %%
with open("data/professions/profession.json", 'r') as f3:
    prof = json.load(f3)

# %%
with open("data/views/views.json", 'r') as f4:
    views = json.load(f4)

# %%
with open("data/interest/personal.json", 'r') as f5:
    personal = json.load(f5)

# %%
with open("data/interest/interest.json", 'r') as f6:
    interest = json.load(f6)

# %%
with open("data/interest/socialwork.json", 'r') as f7:
    socialwork = json.load(f7)

# %%
Data = []
for k in range(100):
    P = Person()
    P.set_ID()
    P.set_age()
    P.set_home_address(nepal)
    P.set_foreign_address(world)
    P.set_profession(prof) 
    P.set_date_out()
    P.set_date_return()
    P.set_fund2invest(interest)
    P.set_personal_view(views)
    P.set_gender()
    P.set_interest(personal)
    P.set_remittance()
    P.set_travell(world)
    P.set_social_work(socialwork)

    Data.append({"ID": P.ID,\
                 "age" : P.age,\
                 "gender" : P.gender,\
                 "profession": P.profession,\
                 "interest": P.interest,\
                 "home_address" : P.home_address,\
                 "foreign_address": P.foreign_address,\
                 "date_out": P.date_out,\
                 "date_return":P.date_return,\
                 "fund2invest":P.fund2invest,\
                 "remittance":P.remittance,\
                 "travell":P.travell,\
                 "social_work":P.social_work,\
                 "personal_view":P.personal_view})

# %%
Data[0:10]
# Out:
# [{'ID': '56W4AGDINH',
#   'age': 47,
#   'gender': 'female',
#   'profession': {'major': 'Military Specific Occupations',
#    'branch': 'FirstLine Supervisors of All Other Tactical Operations Specialists\r'},
#   'interest': 'social work',
#   'home_address': {'province': 'PN1',
#    'district': 'Jhapa',
#    'MCP': 'Kanchankawal RM',
#    'ward': 'Ward 5'},
#   'foreign_address': {'country': 'Macedonia-[FYROM]',
#    'ID': 'MK',
#    'lat': '-19.015438',
#    'lon': '29.154857',
#    'city': 'Mahajanga'},
#   'date_out': '2018.2.9',
#   'date_return': '2022.5.22',
#   'fund2invest': {'invetsment sector': '1%',
#    'tourism and hospitality': '8%',
#    'animal husbandary': '7%',
#    'infrastructure': '10%',
#    'cottage industries': '5%',
#    'personal service business': '10%',
#    'retail business': '9%',
#    'consultancy service': '10%',
#    'alternative energy': '4%',
#    'agriculture': '10%',
#    'total_fund': 3729},
#   'remittance': [{'month': 3, 'amount': 438},
#    {'month': 7, 'amount': 531},
#    {'month': 10, 'amount': 446}],
#   'travell': [{'date': '2015.9.13',
#     'place': {'country': 'Guadeloupe', 'city': 'BASSE-TERRE'}},
#    {'date': '2016.4.6',
#     'place': {'country': 'U.S.-Virgin-Islands', 'city': 'Termez'}},
#    {'date': '2017.1.29', 'place': {'country': 'Belize', 'city': 'BELMOPAN'}},
#    {'date': '2017.3.11', 'place': {'country': 'Monaco', 'city': 'MONACO'}},
#    {'date': '2015.6.20', 'place': {'country': 'Serbia', 'city': 'Pancevo'}}],
#   'social_work': [{'date': '2007.11.2', 'work': 'help for disable person'},
#    {'date': '2013.7.15', 'work': 'creating employment'},
#    {'date': '2008.7.3', 'work': 'resolving the conflict'},
#    {'date': '2008.6.7', 'work': 'security plan'}],
#   'personal_view': ['A day after the Panama Papers were exposed in April 2016, the Department of Money Laundering Investigation promised it would ‘begin a probe’ after calling a meeting of key stakeholders including the Financial Information Unit of Nepal Rastra Bank, the Department of Revenue Investigation and the Nepal Police. Following the meeting, the head of the Department of Money Laundering Investigation promised to adopt a ‘risk-based supervision system’ and claimed that the Financial Information Unit and the Central Investigation Bureau of the Nepal Police would ‘conduct an investigation’. As recent revelations have indicated, the investigations reaped minimal results in the last two years.']},
#  {'ID': 'K20604L1K2',
#   'age': 26,
#   'gender': 'female',
#   'profession': {'major': 'Installation, Maintenance, and Repair Occupations',
#    'branch': 'Bus and Truck Mechanics and Diesel Engine Specialists'},
#   'interest': 'teaching',
#   'home_address': {'province': 'PN3',
#    'district': 'Nukuwot',
#    'MCP': 'Dupcheshwor RM',
#    'ward': 'Ward 1'},
#   'foreign_address': {'country': 'Kenya',
#    'ID': 'KE',
#    'lat': '-19.015438',
#    'lon': '29.154857',
#    'city': 'Nyeri'},
#   'date_out': '2012.2.14',
#   'date_return': '2019.3.19',
#   'fund2invest': {'invetsment sector': '9%',
#    'tourism and hospitality': '10%',
#    'animal husbandary': '3%',
#    'infrastructure': '3%',
#    'cottage industries': '6%',
#    'personal service business': '2%',
#    'retail business': '3%',
#    'consultancy service': '7%',
#    'alternative energy': '3%',
#    'agriculture': '7%',
#    'total_fund': 7178},
#   'remittance': [{'month': 5, 'amount': 237},
#    {'month': 2, 'amount': 693},
#    {'month': 4, 'amount': 191}],
#   'travell': [{'date': '2018.1.22',
#     'place': {'country': 'Norway', 'city': 'OSLO'}},
#    {'date': '2010.4.12', 'place': {'country': 'China', 'city': 'Linyi'}},
#    {'date': '2015.12.1',
#     'place': {'country': 'Cape-Verde', 'city': 'Pinar del Río'}},
#    {'date': '2014.2.20', 'place': {'country': 'Canada', 'city': 'Barrie'}}],
#   'social_work': [{'date': '2004.9.17',
#     'work': 'awareness programme for maternal women'},
#    {'date': '2009.10.1', 'work': 'medical camp'},
#    {'date': '2004.4.1', 'work': 'awareness programme for maternal women'}],
#   'personal_view': ['To add to the erroneous logic, Kathmandu Metropolitan City also recently issued a ‘crackdown on litter-bugs’—if officials find people throwing any form of waste on the city’s roads, they will be fined up to Rs.5,000. These fines overlook a glaring reality: dustbins are scarce. Rather than spending a gross amount of money on a few ‘smart dustbins’, why not invest money in ensuring that regular old dustbins are available at every street corner? Or why not redirect attention towards working with the central government to battle the city’s enduring waste management crisis? These steps would address much more than a 6-lakh-worth-of-a-dustbin ever could.']},
#  {'ID': '9A7WF73KRI',
#   'age': 42,
#   'gender': 'female',
#   'profession': {'major': 'Construction and Extraction Occupations',
#    'branch': 'HelpersExtraction Workers'},
#   'interest': 'singing',
#   'home_address': {'province': 'PN7',
#    'district': 'Doti',
#    'MCP': 'Jorayal RM',
#    'ward': 'Ward 2'},
#   'foreign_address': {'country': 'Laos',
#    'ID': 'LA',
#    'lat': '-19.015438',
#    'lon': '29.154857',
#    'city': 'Rudni'},
#   'date_out': '2017.6.22',
#   'date_return': '2023.4.3',
#   'fund2invest': {'invetsment sector': '6%',
#    'tourism and hospitality': '10%',
#    'animal husbandary': '7%',
#    'infrastructure': '4%',
#    'cottage industries': '2%',
#    'personal service business': '8%',
#    'retail business': '5%',
#    'consultancy service': '3%',
#    'alternative energy': '6%',
#    'agriculture': '1%',
#    'total_fund': 3829},
#   'remittance': [{'month': 10, 'amount': 976},
#    {'month': 10, 'amount': 939},
#    {'month': 3, 'amount': 340},
#    {'month': 5, 'amount': 104},
#    {'month': 10, 'amount': 708}],
#   'travell': [{'date': '2019.12.23',
#     'place': {'country': 'Trinidad-and-Tobago', 'city': "NUKU'ALOFA"}},
#    {'date': '2016.9.16',
#     'place': {'country': 'Uzbekistan', 'city': 'Namangan'}},
#    {'date': '2012.5.15', 'place': {'country': 'Finland', 'city': 'Oulu'}},
#    {'date': '2016.9.19', 'place': {'country': 'Uruguay', 'city': 'Salto'}},
#    {'date': '2010.7.4', 'place': {'country': 'Egypt', 'city': 'Akhmim'}}],
#   'social_work': [{'date': '2015.4.7', 'work': 'community forest'},
#    {'date': '2004.7.27', 'work': 'help for disable person'},
#    {'date': '2010.3.4', 'work': 'voice against racism'}],
#   'personal_view': ['In this discouraging context, the call for a probe is far from enough. Until the probe is supplemented with a clear and targeted strategy, the call is meaningless and can not be deemed an adequate response to the Centre for Investigative Journalism-Nepal’s report. One would also think that a necessary prerequisite for a probe would be a well-monitored committee to issue it. At the risk of adding yet another example to its (now growing) list of hollow and foundationless promises, the officials concerned must demonstrate their claimed commitment through tangible results.As Nepal’s third mutual evaluation report by the Financial Action Task Force (FATF), a global anti-money laundering watchdog, is nearing its 2020 deadline, time is of the essence—especially as the country faces potential blacklisting. In 2010, when FATF included Nepal in its list of ‘nations that failed to comply with the action plan related to anti-money laundering and combating financing of terrorists’, the government leapt into action, making tangible strides in improving anti-money laundering strategies.']},
#  {'ID': '37960R7LP6',
#   'age': 49,
#   'gender': 'female',
#   'profession': {'major': 'Management Occupations',
#    'branch': 'Social and Community Service Managers'},
#   'interest': 'business',
#   'home_address': {'province': 'PN5',
#    'district': 'Rolpa',
#    'MCP': 'Runti Gadhi RM',
#    'ward': 'Ward 3'},
#   'foreign_address': {'country': 'Guinea-Bissau',
#    'ID': 'GW',
#    'lat': '-19.015438',
#    'lon': '29.154857',
#    'city': 'BISSAU'},
#   'date_out': '2019.12.6',
#   'date_return': '2023.4.22',
#   'fund2invest': {'invetsment sector': '8%',
#    'tourism and hospitality': '9%',
#    'animal husbandary': '2%',
#    'infrastructure': '2%',
#    'cottage industries': '10%',
#    'personal service business': '4%',
#    'retail business': '10%',
#    'consultancy service': '2%',
#    'alternative energy': '1%',
#    'agriculture': '3%',
#    'total_fund': 4424},
#   'remittance': [{'month': 2, 'amount': 614},
#    {'month': 2, 'amount': 394},
#    {'month': 10, 'amount': 833},
#    {'month': 10, 'amount': 299},
#    {'month': 9, 'amount': 457},
#    {'month': 11, 'amount': 548}],
#   'travell': [{'date': '2019.12.21',
#     'place': {'country': 'Iran', 'city': 'Erbil'}},
#    {'date': '2017.5.8',
#     'place': {'country': 'Guatemala', 'city': 'CUIDAD DE GUATEMALA'}}],
#   'social_work': [{'date': '2010.12.5', 'work': 'building temples'},
#    {'date': '2014.11.16', 'work': 'fitness programme'}],
#   'personal_view': ['A day after the Panama Papers were exposed in April 2016, the Department of Money Laundering Investigation promised it would ‘begin a probe’ after calling a meeting of key stakeholders including the Financial Information Unit of Nepal Rastra Bank, the Department of Revenue Investigation and the Nepal Police. Following the meeting, the head of the Department of Money Laundering Investigation promised to adopt a ‘risk-based supervision system’ and claimed that the Financial Information Unit and the Central Investigation Bureau of the Nepal Police would ‘conduct an investigation’. As recent revelations have indicated, the investigations reaped minimal results in the last two years.']},
#  {'ID': '161ROIL2W3',
#   'age': 38,
#   'gender': 'female',
#   'profession': {'major': 'Production Occupations',
#    'branch': 'Computer Numerically Controlled Tool Operators'},
#   'interest': 'movies',
#   'home_address': {'province': 'PN4',
#    'district': 'Manang',
#    'MCP': 'Nesyang RM',
#    'ward': 'Ward 9'},
#   'foreign_address': {'country': 'Rwanda',
#    'ID': 'RW',
#    'lat': '-19.015438',
#    'lon': '29.154857',
#    'city': 'KIGALI'},
#   'date_out': '2018.7.23',
#   'date_return': '2021.8.6',
#   'fund2invest': {'invetsment sector': '10%',
#    'tourism and hospitality': '5%',
#    'animal husbandary': '2%',
#    'infrastructure': '6%',
#    'cottage industries': '3%',
#    'personal service business': '7%',
#    'retail business': '6%',
#    'consultancy service': '9%',
#    'alternative energy': '8%',
#    'agriculture': '7%',
#    'total_fund': 8184},
#   'remittance': [{'month': 11, 'amount': 516},
#    {'month': 5, 'amount': 483},
#    {'month': 11, 'amount': 400},
#    {'month': 8, 'amount': 742},
#    {'month': 8, 'amount': 757}],
#   'travell': [{'date': '2016.7.29',
#     'place': {'country': 'Mayotte', 'city': 'Al-Mukalla'}},
#    {'date': '2015.8.2', 'place': {'country': 'Iceland', 'city': 'REYKJAVIK'}},
#    {'date': '2015.3.1', 'place': {'country': 'Libya', 'city': 'RIGA'}},
#    {'date': '2013.8.1',
#     'place': {'country': 'Guadeloupe', 'city': 'Pointe-à-Pitre'}}],
#   'social_work': [{'date': '2011.4.4', 'work': 'community forest'},
#    {'date': '2017.10.14', 'work': 'society development project'},
#    {'date': '2013.4.30', 'work': 'skill development training'},
#    {'date': '2003.9.1', 'work': 'food and nutrition education'},
#    {'date': '2017.7.8', 'work': 'pollution control'}],
#   'personal_view': ['In response to the pressure, Parliament devised several legislative measures to monitor money laundering—including the endorsement of the Anti-Money Laundering Act and the establishment of the Department of Money Laundering Investigation in 2011. After being removed from the FATF’s watch list in June 2011, the government seemingly forgot about its commitment to the cause. In the seven years of existence, the Department of Money Laundering Investigation has filed a meagre 40 money laundering cases at the Special Court, and most of them against petty or more low-profile violators. In the past three years, only 10 cases were filed, most of them related to minor charges. This points to a dismal conclusion: Issues related to money laundering only seem to matter when global monitoring organisations intervene']},
#  {'ID': '45P8ATH4M8',
#   'age': 25,
#   'gender': 'female',
#   'profession': {'major': 'Installation, Maintenance, and Repair Occupations',
#    'branch': 'Camera and Photographic Equipment Repairers'},
#   'interest': 'social work',
#   'home_address': {'province': 'PN4',
#    'district': 'Lamjung',
#    'MCP': 'Marsyangdi RM',
#    'ward': 'Ward 5'},
#   'foreign_address': {'country': 'Thailand',
#    'ID': 'TH',
#    'lat': '-19.015438',
#    'lon': '29.154857',
#    'city': 'Nan'},
#   'date_out': '2015.11.10',
#   'date_return': '2023.6.24',
#   'fund2invest': {'invetsment sector': '6%',
#    'tourism and hospitality': '5%',
#    'animal husbandary': '9%',
#    'infrastructure': '2%',
#    'cottage industries': '6%',
#    'personal service business': '5%',
#    'retail business': '9%',
#    'consultancy service': '7%',
#    'alternative energy': '1%',
#    'agriculture': '4%',
#    'total_fund': 1484},
#   'remittance': [{'month': 12, 'amount': 468},
#    {'month': 12, 'amount': 539},
#    {'month': 1, 'amount': 265},
#    {'month': 3, 'amount': 593},
#    {'month': 1, 'amount': 866}],
#   'travell': [{'date': '2013.1.25',
#     'place': {'country': 'Saudi-Arabia', 'city': 'Gitarama'}},
#    {'date': '2013.12.12',
#     'place': {'country': 'Antarctica', 'city': 'Gyumri (Leninakan)'}},
#    {'date': '2012.9.2',
#     'place': {'country': 'Saint-Kitts-and-Nevis', 'city': 'MORONI'}},
#    {'date': '2018.6.21', 'place': {'country': 'France', 'city': 'Le Havre'}}],
#   'social_work': [{'date': '2015.11.29', 'work': 'culture saving programme'},
#    {'date': '2017.7.9', 'work': 'pollution control'},
#    {'date': '2011.2.1', 'work': 'food and nutrition education'},
#    {'date': '2005.1.12', 'work': 'resolving the conflict'}],
#   'personal_view': ['The move to shut down these services outright without much deliberation between stakeholder groups is a disservice to commuters and entrepreneurs. Tootle and Pathao are popular services that have made the lives of capital residents much easier by providing a middle-ground option for commuters: more comfortable than public transportation and more affordable than taxis. It is much easier to get in touch with a rider using an app on their phone, hop in, and get to the destination relatively faster and at a much cheaper rate. At the same time, these ride-hailing services are providing employment opportunities to many in the city.']},
#  {'ID': '509B8TQX99',
#   'age': 29,
#   'gender': 'female',
#   'profession': {'major': 'Protective Service Occupations',
#    'branch': 'Transit and Railroad Police'},
#   'interest': 'history',
#   'home_address': {'province': 'PN7',
#    'district': 'Bajhang',
#    'MCP': 'Kanda RM',
#    'ward': 'Ward 5'},
#   'foreign_address': {'country': 'Jordan',
#    'ID': 'JO',
#    'lat': '-19.015438',
#    'lon': '29.154857',
#    'city': 'Irbid'},
#   'date_out': '2017.6.21',
#   'date_return': '2025.5.11',
#   'fund2invest': {'invetsment sector': '1%',
#    'tourism and hospitality': '7%',
#    'animal husbandary': '5%',
#    'infrastructure': '5%',
#    'cottage industries': '3%',
#    'personal service business': '2%',
#    'retail business': '3%',
#    'consultancy service': '5%',
#    'alternative energy': '3%',
#    'agriculture': '8%',
#    'total_fund': 7672},
#   'remittance': [{'month': 2, 'amount': 297},
#    {'month': 4, 'amount': 781},
#    {'month': 4, 'amount': 764},
#    {'month': 6, 'amount': 137},
#    {'month': 8, 'amount': 720}],
#   'travell': [{'date': '2011.6.22',
#     'place': {'country': 'El-Salvador', 'city': 'PARAMARIBO'}},
#    {'date': '2012.2.28', 'place': {'country': 'Libya', 'city': 'Daugavpils'}}],
#   'social_work': [{'date': '2010.10.29', 'work': 'building temples'},
#    {'date': '2006.8.13', 'work': 'small industries for women'},
#    {'date': '2015.9.21', 'work': 'drinking water management'}],
#   'personal_view': ['When the Centre for Investigative Journalism-Nepal released its report revealing how over 50 Nepalis exploited secretive tax regimes and broke the country’s law by investing in different offshore companies, sections of the public eagerly anticipated a swift and stringent response from the government. And when the Prime Minister’s Office directed the Financial Information Unit under Nepal Rastra Bank to expedite ‘a probe into businesses and businesspeople’ last week, those steps appeared to be making ground—at least upon cursory examination. The promise of a ‘serious probe’ devoid of any comprehensive strategy is not only wholly inadequate but also frustratingly familiar.An almost parallel call was made three years ago, when the Panama Papers, leaked by the International Consortium of Investigative Journalists, revealed the names of more than 20 Nepalis parking their wealth in a number of tax haven countries and territories.']},
#  {'ID': '9J7JQ993ZJ',
#   'age': 34,
#   'gender': 'female',
#   'profession': {'major': 'Food Preparation and Serving Related Occupations',
#    'branch': 'Cooks, All Other'},
#   'interest': 'stocks',
#   'home_address': {'province': 'PN2',
#    'district': 'Parsa',
#    'MCP': 'Subarnapur RM',
#    'ward': 'Ward 7'},
#   'foreign_address': {'country': 'Hong-Kong',
#    'ID': 'HK',
#    'lat': '-19.015438',
#    'lon': '29.154857',
#    'city': 'GEORGETOWN'},
#   'date_out': '2011.1.24',
#   'date_return': '2025.9.11',
#   'fund2invest': {'invetsment sector': '7%',
#    'tourism and hospitality': '8%',
#    'animal husbandary': '3%',
#    'infrastructure': '8%',
#    'cottage industries': '9%',
#    'personal service business': '10%',
#    'retail business': '1%',
#    'consultancy service': '8%',
#    'alternative energy': '1%',
#    'agriculture': '1%',
#    'total_fund': 8339},
#   'remittance': [{'month': 12, 'amount': 741},
#    {'month': 9, 'amount': 560},
#    {'month': 1, 'amount': 355},
#    {'month': 4, 'amount': 494},
#    {'month': 3, 'amount': 480},
#    {'month': 3, 'amount': 544}],
#   'travell': [{'date': '2018.11.24',
#     'place': {'country': 'India', 'city': 'Serilingampalle'}},
#    {'date': '2019.3.27', 'place': {'country': 'Taiwan', 'city': 'FUNAFUTI'}},
#    {'date': '2010.6.4',
#     'place': {'country': 'Greece', 'city': 'Thessaloniki'}}],
#   'social_work': [{'date': '2007.7.21', 'work': 'helping the homeless'},
#    {'date': '2004.4.2', 'work': 'security plan'},
#    {'date': '2010.4.5', 'work': 'resolving the conflict'},
#    {'date': '2018.9.17', 'work': 'society development project'},
#    {'date': '2008.7.14', 'work': 'child orphanage'}],
#   'personal_view': ['To add to the erroneous logic, Kathmandu Metropolitan City also recently issued a ‘crackdown on litter-bugs’—if officials find people throwing any form of waste on the city’s roads, they will be fined up to Rs.5,000. These fines overlook a glaring reality: dustbins are scarce. Rather than spending a gross amount of money on a few ‘smart dustbins’, why not invest money in ensuring that regular old dustbins are available at every street corner? Or why not redirect attention towards working with the central government to battle the city’s enduring waste management crisis? These steps would address much more than a 6-lakh-worth-of-a-dustbin ever could.']},
#  {'ID': '356S6WVAZG',
#   'age': 49,
#   'gender': 'female',
#   'profession': {'major': 'Management Occupations',
#    'branch': 'Natural Sciences Managers'},
#   'interest': 'social work',
#   'home_address': {'province': 'PN2',
#    'district': 'Rautahat',
#    'MCP': 'Paroha RM',
#    'ward': 'Ward 3'},
#   'foreign_address': {'country': 'Comoros',
#    'ID': 'KM',
#    'lat': '-19.015438',
#    'lon': '29.154857',
#    'city': 'MORONI'},
#   'date_out': '2011.5.18',
#   'date_return': '2022.2.3',
#   'fund2invest': {'invetsment sector': '3%',
#    'tourism and hospitality': '2%',
#    'animal husbandary': '9%',
#    'infrastructure': '4%',
#    'cottage industries': '1%',
#    'personal service business': '1%',
#    'retail business': '4%',
#    'consultancy service': '4%',
#    'alternative energy': '3%',
#    'agriculture': '6%',
#    'total_fund': 4762},
#   'remittance': [{'month': 11, 'amount': 822},
#    {'month': 11, 'amount': 624},
#    {'month': 3, 'amount': 115}],
#   'travell': [{'date': '2019.7.19',
#     'place': {'country': 'Saint-Kitts-and-Nevis', 'city': 'MORONI'}},
#    {'date': '2010.10.23',
#     'place': {'country': 'United-Kingdom', 'city': 'Port-Gentil'}},
#    {'date': '2017.6.15',
#     'place': {'country': 'Greenland', 'city': 'NUUK (GODTHAB)'}},
#    {'date': '2019.6.8', 'place': {'country': 'Lebanon', 'city': 'BEIRUT'}},
#    {'date': '2014.11.28',
#     'place': {'country': 'Finland', 'city': 'Jyvaskyla'}}],
#   'social_work': [{'date': '2006.9.7', 'work': 'workshop for young'},
#    {'date': '2012.7.6', 'work': 'work against human trafficking'}],
#   'personal_view': ['Kathmandu Metropolitan City’s undying infatuation for the preface ‘smart’ has manifested in several glossy (and costly) infrastructural undertakings—from zebra crossings to dustbins and even toilets. But contrary to what ‘smart’ suggests, many of these initiatives seem devoid of any intelligent or sustainable solutions to the challenges they claim to address.Take, for example, the ‘smart dustbins’. From November last year, Kathmandu Metropolitan City, in conjunction with its private partner Krishna Suppliers, began scattering over 70 ‘smart dustbins’ throughout the city. According to city officials, each dustbin, which is fitted with advertising technology, costs around Rs 600,000. The city plans to install as many as 200 of them—which means the investment will amount to Rs 120,000,000. As of yet, the ‘smart dustbins’ seem to have made little difference—and in painful visual irony, some of them are even decorated with litter.']},
#  {'ID': '03IN0DY66R',
#   'age': 36,
#   'gender': 'female',
#   'profession': {'major': 'Protective Service Occupations',
#    'branch': 'Detectives and Criminal Investigators'},
#   'interest': 'travel',
#   'home_address': {'province': 'PN5',
#    'district': 'Pyuthan',
#    'MCP': 'Pyuthan MCP',
#    'ward': 'Ward 1'},
#   'foreign_address': {'country': 'Timor-Leste',
#    'ID': 'TL',
#    'lat': '-19.015438',
#    'lon': '29.154857',
#    'city': 'DILI'},
#   'date_out': '2011.10.26',
#   'date_return': '2023.5.5',
#   'fund2invest': {'invetsment sector': '2%',
#    'tourism and hospitality': '7%',
#    'animal husbandary': '2%',
#    'infrastructure': '9%',
#    'cottage industries': '6%',
#    'personal service business': '10%',
#    'retail business': '10%',
#    'consultancy service': '6%',
#    'alternative energy': '3%',
#    'agriculture': '3%',
#    'total_fund': 2069},
#   'remittance': [{'month': 7, 'amount': 734},
#    {'month': 10, 'amount': 486},
#    {'month': 6, 'amount': 796},
#    {'month': 12, 'amount': 731},
#    {'month': 2, 'amount': 767},
#    {'month': 10, 'amount': 790}],
#   'travell': [{'date': '2012.2.19',
#     'place': {'country': 'Sierra-Leone', 'city': 'Kosice'}},
#    {'date': '2018.1.23', 'place': {'country': 'Austria', 'city': 'Bregenz'}},
#    {'date': '2015.9.5',
#     'place': {'country': 'Philippines', 'city': 'Taguig'}}],
#   'social_work': [{'date': '2011.2.19',
#     'work': 'education programmee for infant and mother'},
#    {'date': '2004.10.22', 'work': 'work for physically disable person'},
#    {'date': '2010.1.8', 'work': 'building temples'},
#    {'date': '2002.9.6', 'work': 'community forest'},
#    {'date': '2004.8.1', 'work': 'medical camp'}],
#   'personal_view': ['To add to the erroneous logic, Kathmandu Metropolitan City also recently issued a ‘crackdown on litter-bugs’—if officials find people throwing any form of waste on the city’s roads, they will be fined up to Rs.5,000. These fines overlook a glaring reality: dustbins are scarce. Rather than spending a gross amount of money on a few ‘smart dustbins’, why not invest money in ensuring that regular old dustbins are available at every street corner? Or why not redirect attention towards working with the central government to battle the city’s enduring waste management crisis? These steps would address much more than a 6-lakh-worth-of-a-dustbin ever could.']}]

# %%
with open("data/database/sample.json","w")as fw:
    json.dump(Data,fw)
